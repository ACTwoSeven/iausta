# %% [markdown]
# <a href="https://colab.research.google.com/github/ACTwoSeven/iausta/blob/main/fuzzy/S1_C2_FUZZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando la librería

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 9.8 MB/s eta 0:00:00
# ...

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Ejercicio 1
# Graficar variables de temperatura

# %%
temp = ctrl.Antecedent(np.arange(80, 110, 1), 'Temperatura')
temp['Alta']=fuzz.trapmf(temp.universe, [80, 80, 90, 100])
temp['MuyAlta']=fuzz.trapmf(temp.universe, [90, 100, 110,110])
temp.view()

# %% [markdown]
# #Tres funciones de pertenencia
# Agregar temperatura media

# %%
temp = ctrl.Antecedent(np.arange(60, 110, 1), 'Temperatura')
temp['Media']=fuzz.trapmf(temp.universe, [60, 60, 70, 80])
temp['Alta']=fuzz.trapmf(temp.universe, [70, 80, 90, 100])
temp['MuyAlta']=fuzz.trapmf(temp.universe, [90, 100, 110,110])
temp.view()
